# %% [markdown]
# # Week 10 Hand-in

# %% [markdown]
# ## Assignment
#
# https://github.com/Hartmannsolution/docker_notebooks/blob/master/notebooks/12Exercise.ipynb

# %% [markdown]
# ## Status

# %% [markdown]
# # Imports

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# ## Part 1

# %%
apple_loc = 'images/apple1.jpeg'

img = cv2.imread(apple_loc)   # Read the image
print(type(img),img.shape)
plt.imshow(img)   # Ploting the image using matplotlib
plt.figure()
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
# Out:
# <class 'numpy.ndarray'> (240, 210, 3)
