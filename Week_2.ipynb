# %% [markdown]
# # Week 2 Hand-in

# %% [markdown]
# ## Assignment
# Txt for week 2 assignment

# %% [markdown]
# ## Status
# 1.1 a, b, c have been finished - the rest of the assignment have been reflected upon

# %% [markdown]
# ## Solution for ex 1

# %%
from modules.week_2 import Exercise1
Exercise1.print_file_content("/home/jovyan/python_handin_template/modules/week_2/country_codes.csv")
# Out:
# Afghanistan 	AF 	AFG 	004
# Albania 	AL 	ALB 	008
# Algeria 	DZ 	DZA 	012
# American Samoa 	AS 	ASM 	016
# Andorra 	AD 	AND 	020
# Angola 	AO 	AGO 	024
# Anguilla 	AI 	AIA 	660
# Antarctica 	AQ 	ATA 	010
# Antigua and Barbuda 	AG 	ATG 	028
# Argentina 	AR 	ARG 	032
# Armenia 	AM 	ARM 	051
# Aruba 	AW 	ABW 	533
# Australia 	AU 	AUS 	036
# Austria 	AT 	AUT 	040
# Azerbaijan 	AZ 	AZE 	031
# Bahamas (the) 	BS 	BHS 	044
# Bahrain 	BH 	BHR 	048
# Bangladesh 	BD 	BGD 	050
# Barbados 	BB 	BRB 	052
# Belarus 	BY 	BLR 	112
# Belgium 	BE 	BEL 	056
# Belize 	BZ 	BLZ 	084
# Benin 	BJ 	BEN 	204
# Bermuda 	BM 	BMU 	060
# Bhutan 	BT 	BTN 	064
# Bolivia (Plurinational State of) 	BO 	BOL 	068
# Bonaire, Sint Eustatius and Saba 	BQ 	BES 	535
# Bosnia and Herzegovina 	BA 	BIH 	070
# Botswana 	BW 	BWA 	072
# Bouvet Island 	BV 	BVT 	074
# Brazil 	BR 	BRA 	076
# British Indian Ocean Territory (the) 	IO 	IOT 	086
# Brunei Darussalam 	BN 	BRN 	096
# Bulgaria 	BG 	BGR 	100
# Burkina Faso 	BF 	BFA 	854
# ...

# %%
from modules.week_2 import Exercise1

file = "modules/week_2/testtxt.txt"
lstT = [("elm1", "elm2", "elm3"),("elm12","elm13","elm14")]

Exercise1.write_list_to_file(file, lstT)

# %%
from modules.week_2 import Exercise1

file = "/home/jovyan/python_handin_template/modules/week_2/country_codes.csv"

lst = Exercise1.read_csv(file)
print(lst)
# Out:
# [['Albania \tAL \tALB \t008'], ['Algeria \tDZ \tDZA \t012'], ['American Samoa \tAS \tASM \t016'], ['Andorra \tAD \tAND \t020'], ['Angola \tAO \tAGO \t024'], ['Anguilla \tAI \tAIA \t660'], ['Antarctica \tAQ \tATA \t010'], ['Antigua and Barbuda \tAG \tATG \t028'], ['Argentina \tAR \tARG \t032'], ['Armenia \tAM \tARM \t051'], ['Aruba \tAW \tABW \t533'], ['Australia \tAU \tAUS \t036'], ['Austria \tAT \tAUT \t040'], ['Azerbaijan \tAZ \tAZE \t031'], ['Bahamas (the) \tBS \tBHS \t044'], ['Bahrain \tBH \tBHR \t048'], ['Bangladesh \tBD \tBGD \t050'], ['Barbados \tBB \tBRB \t052'], ['Belarus \tBY \tBLR \t112'], ['Belgium \tBE \tBEL \t056'], ['Belize \tBZ \tBLZ \t084'], ['Benin \tBJ \tBEN \t204'], ['Bermuda \tBM \tBMU \t060'], ['Bhutan \tBT \tBTN \t064'], ['Bolivia (Plurinational State of) \tBO \tBOL \t068'], ['Bonaire', ' Sint Eustatius and Saba \tBQ \tBES \t535'], ['Bosnia and Herzegovina \tBA \tBIH \t070'], ['Botswana \tBW \tBWA \t072'], ['Bouvet Island \tBV \tBVT \t074'], ['Brazil \tBR \tBRA
# ...
